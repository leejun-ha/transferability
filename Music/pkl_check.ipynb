# %%
import pickle
import torch

file_path = '/home/junha/dna_classification/Music/data/maestro-v1.0.0/maestro-v1_bert-base-uncased_token_map.pkl'  # Replace with your actual file path

# try:
with open(file_path, 'rb') as file:
    data = torch.load(file)
print(f"Type of loaded data: {type(data)}")
print("Contents of the PKL file:")
print(data)
# except FileNotFoundError:
#     print("File not found. Check the file path.")
# except pickle.UnpicklingError:
#     print("The file is not a valid pickle file.")
# except EOFError:
#     print("The file is empty or corrupted.")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
# Out:
# Type of loaded data: <class 'torch.nn.modules.sparse.Embedding'>
# Contents of the PKL file:
# Embedding(256, 1)

# %%
# Print the shape of the embedding weight
print(f"Embedding weight shape: {data.weight.shape}")

# Print the number of embeddings and embedding dimension
print(f"Number of embeddings: {data.num_embeddings}")
print(f"Embedding dimension: {data.embedding_dim}")

# Print the actual embedding weights
print("Embedding weights:")
print(data.weight)

# If you want to see a specific embedding vector
print("First embedding vector:")
print(data.weight[0])

# Check if padding_idx is set
print(f"Padding index: {data.padding_idx}")

# Check if the embeddings are frozen
print(f"Embeddings frozen: {data.weight.requires_grad == False}")
# Out:
# Embedding weight shape: torch.Size([256, 1])
# Number of embeddings: 256
# Embedding dimension: 1
# Embedding weights:
# Parameter containing:
# tensor([[13685.],
#         [24009.],
#         [20278.],
#         [21370.],
#         [22659.],
#         [10681.],
#         [20579.],
#         [24871.],
#         [21654.],
#         [22826.],
#         [23804.],
#         [16239.],
#         [21390.],
#         [18828.],
#         [11114.],
#         [21846.],
#         [16113.],
#         [25239.],
#         [21771.],
#         [12015.],
#         [25139.],
#         [23741.],
#         [29063.],
#         [22609.],
#         [14533.],
#         [18029.],
#         [21343.],
#         [12979.],
#         [28257.],
#         [22924.],
#         [20693.],
#         [27804.],
#         [27543.],
#         [22286.],
#         [24655.],
#         [15829.],
#         [20937.],
#         [20691.],
#         [ 9913.],
#         [16968.],
#         [ 9538.],
#         [16696.],
#         [14579.],
#         [16346.],
#         [15490.],
#         [14148.],
#         [17343.],
#         [17555.],
#         [23681.],
#         [19019.],
#         [22626.],
#         [24669.],
#         [15297.],
#         [22914.],
#         [20546.],
#         [23778.],
#         [20489.],
#         [16626.],
#         [20610.],
#         [18693.],
#         [19524.],
#         [28126.],
#         [25739.],
#         [19460.],
#         [ 8537.],
#         [ 1110.],
#         [30254.],
#         [17755.],
#         [ 1572.],
#         [ 1104.],
#         [ 1940.],
#         [ 7335.],
#         [20780.],
#         [24107.],
#         [ 1741.],
#         [22456.],
#         [30265.],
#         [15229.],
#         [29655.],
#         [ 1897.],
#         [ 1577.],
#         [  355.],
#         [  882.],
#         [ 1342.],
#         [30291.],
#         [29625.],
#         [  184.],
#         [29699.],
#         [29682.],
#         [  518.],
#         [  614.],
#         [  419.],
#         [ 1551.],
#         [ 1154.],
#         [  170.],
#         [25597.],
#         [28294.],
#         [19353.],
#         [29411.],
#         [26063.],
#         [28520.],
#         [28087.],
#         [25752.],
#         [28019.],
#         [22304.],
#         [ 1878.],
#         [26341.],
#         [20647.],
#         [27298.],
#         [24721.],
#         [28452.],
#         [25750.],
#         [26099.],
#         [28783.],
#         [23620.],
#         [15414.],
#         [29399.],
#         [26042.],
#         [29545.],
#         [25181.],
#         [28674.],
#         [28668.],
#         [26138.],
#         [27810.],
#         [28570.],
#         [ 1746.],
#         [24543.],
#         [14576.],
#         [15763.],
#         [13953.],
#         [13946.],
#         [13247.],
#         [17345.],
#         [13884.],
#         [20492.],
#         [10926.],
#         [14732.],
#         [ 7567.],
#         [29025.],
#         [22160.],
#         [12598.],
#         [16562.],
#         [ 9727.],
#         [11588.],
#         [13341.],
#         [12741.],
#         [12497.],
#         [14697.],
#         [13146.],
#         [15307.],
#         [ 9422.],
#         [10986.],
#         [15305.],
#         [ 9482.],
#         [ 8149.],
#         [ 9255.],
#         [10071.],
#         [ 8468.],
#         [13033.],
#         [10422.],
#         [ 7036.],
#         [ 8323.],
#         [ 8341.],
#         [ 8980.],
#         [15094.],
#         [18845.],
#         [ 6773.],
#         [ 4872.],
#         [20049.],
#         [ 7042.],
#         [ 7819.],
#         [11737.],
#         [ 7056.],
#         [18804.],
#         [ 6503.],
#         [ 6026.],
#         [ 5186.],
#         [ 5427.],
#         [ 4855.],
#         [ 4849.],
#         [10450.],
#         [ 4846.],
#         [ 4679.],
#         [ 8183.],
#         [ 4304.],
#         [ 3017.],
#         [ 3234.],
#         [ 3977.],
#         [ 2327.],
#         [ 3310.],
#         [ 1996.],
#         [ 3016.],
#         [ 2622.],
#         [ 1057.],
#         [ 3760.],
#         [ 1017.],
#         [ 3673.],
#         [ 2468.],
#         [ 3251.],
#         [ 3737.],
#         [ 2804.],
#         [ 3554.],
#         [ 2823.],
#         [ 4113.],
#         [ 4533.],
#         [ 5149.],
#         [ 5444.],
#         [ 4802.],
#         [25869.],
#         [ 5538.],
#         [ 5781.],
#         [11663.],
#         [ 6543.],
#         [ 3553.],
#         [ 6431.],
#         [11332.],
#         [ 6690.],
#         [ 6570.],
#         [ 9513.],
#         [ 8846.],
#         [ 6195.],
#         [ 8199.],
#         [ 8854.],
#         [19231.],
#         [ 9367.],
#         [ 8570.],
#         [ 9583.],
#         [16856.],
#         [14672.],
#         [11049.],
#         [10173.],
#         [ 5698.],
#         [11208.],
#         [10423.],
#         [11730.],
#         [12624.],
#         [10192.],
#         [15205.],
#         [15025.],
#         [23941.],
#         [11547.],
#         [16209.],
#         [16327.],
#         [17058.],
#         [16240.],
#         [13784.],
#         [13429.],
#         [12648.],
#         [ 8576.],
#         [14818.],
#         [19329.],
#         [25970.],
#         [15648.],
#         [21298.],
#         [11881.],
#         [30520.]], requires_grad=True)
# First embedding vector:
# tensor([13685.], grad_fn=<SelectBackward0>)
# Padding index: None
# Embeddings frozen: False

# %%
print(f"Min weight value: {torch.min(data.weight)}")
print(f"Max weight value: {torch.max(data.weight)}")
print(f"Mean weight value: {torch.mean(data.weight)}")
print(f"Standard deviation of weights: {torch.std(data.weight)}")
# Out:
# Min weight value: 170.0
# Max weight value: 30520.0
# Mean weight value: 14685.546875
# Standard deviation of weights: 8801.0029296875
