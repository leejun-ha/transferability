# %%
import pickle
import torch

file_path = '/home/junha/transferability/Music/shift_table/microsoft_codebert-base-mlm_top_256_token_mapping.pkl'  # Replace with your actual file path

# try:
with open(file_path, 'rb') as file:
    data = torch.load(file)
print(f"Type of loaded data: {type(data)}")
print("Contents of the PKL file:")
print(data)
# except FileNotFoundError:
#     print("File not found. Check the file path.")
# except pickle.UnpicklingError:
#     print("The file is not a valid pickle file.")
# except EOFError:
#     print("The file is empty or corrupted.")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
# Out:
# Type of loaded data: <class 'torch.nn.modules.sparse.Embedding'>
# Contents of the PKL file:
# Embedding(256, 1)

# %%
# Print the shape of the embedding weight
print(f"Embedding weight shape: {data.weight.shape}")

# Print the number of embeddings and embedding dimension
print(f"Number of embeddings: {data.num_embeddings}")
print(f"Embedding dimension: {data.embedding_dim}")

# Print the actual embedding weights
print("Embedding weights:")
print(data.weight)

# If you want to see a specific embedding vector
print("First embedding vector:")
print(data.weight[0])

# Check if padding_idx is set
print(f"Padding index: {data.padding_idx}")

# Check if the embeddings are frozen
print(f"Embeddings frozen: {data.weight.requires_grad == False}")
# Out:
# Embedding weight shape: torch.Size([256, 1])
# Number of embeddings: 256
# Embedding dimension: 1
# Embedding weights:
# Parameter containing:
# tensor([[ 2683.],
#         [ 2581.],
#         [ 2620.],
#         [ 2575.],
#         [ 2692.],
#         [ 2475.],
#         [ 2509.],
#         [ 2549.],
#         [ 2487.],
#         [ 2629.],
#         [17465.],
#         [19481.],
#         [22025.],
#         [16703.],
#         [22022.],
#         [21486.],
#         [21926.],
#         [27531.],
#         [19841.],
#         [21057.],
#         [20842.],
#         [23833.],
#         [14142.],
#         [17788.],
#         [23499.],
#         [22907.],
#         [22407.],
#         [22394.],
#         [17914.],
#         [18827.],
#         [24434.],
#         [19317.],
#         [21619.],
#         [23352.],
#         [15136.],
#         [24594.],
#         [16576.],
#         [26224.],
#         [22932.],
#         [20958.],
#         [22610.],
#         [23632.],
#         [14526.],
#         [23777.],
#         [16147.],
#         [17134.],
#         [16932.],
#         [16068.],
#         [18139.],
#         [19961.],
#         [12521.],
#         [21472.],
#         [16048.],
#         [11387.],
#         [16086.],
#         [21084.],
#         [12740.],
#         [28756.],
#         [26187.],
#         [10790.],
#         [27009.],
#         [28154.],
#         [26976.],
#         [22275.],
#         [27814.],
#         [24087.],
#         [22203.],
#         [25746.],
#         [28311.],
#         [12376.],
#         [ 5401.],
#         [24096.],
#         [ 4029.],
#         [ 8889.],
#         [ 4724.],
#         [ 4805.],
#         [ 6079.],
#         [ 4261.],
#         [ 4464.],
#         [ 5187.],
#         [ 5179.],
#         [ 6163.],
#         [ 6273.],
#         [ 5139.],
#         [ 4700.],
#         [ 3438.],
#         [ 4466.],
#         [ 6191.],
#         [ 5388.],
#         [ 4008.],
#         [ 4229.],
#         [ 6353.],
#         [ 5354.],
#         [ 5764.],
#         [ 4185.],
#         [ 3515.],
#         [ 5786.],
#         [ 4583.],
#         [ 4720.],
#         [ 4749.],
#         [ 4868.],
#         [ 2753.],
#         [ 3429.],
#         [ 4413.],
#         [ 4601.],
#         [ 4090.],
#         [ 3486.],
#         [ 2871.],
#         [12606.],
#         [ 3963.],
#         [13412.],
#         [20741.],
#         [13138.],
#         [13029.],
#         [14677.],
#         [28332.],
#         [14010.],
#         [11212.],
#         [20294.],
#         [19348.],
#         [16471.],
#         [18613.],
#         [17825.],
#         [29537.],
#         [23688.],
#         [17403.],
#         [13756.],
#         [22018.],
#         [23593.],
#         [14078.],
#         [21679.],
#         [23785.],
#         [10630.],
#         [22343.],
#         [14378.],
#         [12875.],
#         [11899.],
#         [11176.],
#         [20335.],
#         [ 6486.],
#         [13092.],
#         [22234.],
#         [25504.],
#         [27509.],
#         [21489.],
#         [ 6564.],
#         [12457.],
#         [18914.],
#         [13539.],
#         [17696.],
#         [24690.],
#         [20637.],
#         [21035.],
#         [14993.],
#         [19594.],
#         [26271.],
#         [17405.],
#         [ 6535.],
#         [14506.],
#         [18512.],
#         [23712.],
#         [22030.],
#         [22955.],
#         [23380.],
#         [23297.],
#         [25745.],
#         [22904.],
#         [25143.],
#         [14210.],
#         [14168.],
#         [ 6390.],
#         [25113.],
#         [20666.],
#         [28941.],
#         [23285.],
#         [ 5345.],
#         [26231.],
#         [18744.],
#         [20802.],
#         [22777.],
#         [28188.],
#         [29327.],
#         [12963.],
#         [ 8732.],
#         [11118.],
#         [17422.],
#         [12567.],
#         [19711.],
#         [25873.],
#         [16459.],
#         [17332.],
#         [28015.],
#         [16666.],
#         [15028.],
#         [13710.],
#         [14989.],
#         [23532.],
#         [19540.],
#         [19936.],
#         [26963.],
#         [27517.],
#         [24398.],
#         [ 6227.],
#         [ 6070.],
#         [27908.],
#         [13285.],
#         [ 9475.],
#         [29386.],
#         [24673.],
#         [19015.],
#         [26628.],
#         [17014.],
#         [16087.],
#         [15170.],
#         [ 2531.],
#         [23980.],
#         [15471.],
#         [22884.],
#         [28906.],
#         [12904.],
#         [ 9800.],
#         [21005.],
#         [25392.],
#         [ 6036.],
#         [10550.],
#         [ 7558.],
#         [24902.],
#         [27519.],
#         [ 5824.],
#         [26257.],
#         [ 6365.],
#         [16333.],
#         [27234.],
#         [10545.],
#         [19342.],
#         [14748.],
#         [16444.],
#         [24837.],
#         [ 5986.],
#         [ 6282.],
#         [27533.],
#         [12104.],
#         [ 6391.],
#         [16528.],
#         [ 9645.],
#         [25191.],
#         [20636.],
#         [25578.],
#         [ 5585.],
#         [22997.],
#         [27054.],
#         [11518.],
#         [22238.],
#         [15017.],
#         [20304.],
#         [ 6255.]], requires_grad=True)
# First embedding vector:
# tensor([2683.], grad_fn=<SelectBackward0>)
# Padding index: None
# Embeddings frozen: False

# %%
print(f"Min weight value: {torch.min(data.weight)}")
print(f"Max weight value: {torch.max(data.weight)}")
print(f"Mean weight value: {torch.mean(data.weight)}")
print(f"Standard deviation of weights: {torch.std(data.weight)}")
# Out:
# Min weight value: 2475.0
# Max weight value: 29537.0
# Mean weight value: 16094.0859375
# Standard deviation of weights: 8093.49462890625
