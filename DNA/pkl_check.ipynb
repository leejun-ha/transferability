# %%
import pickle
import torch

file_path = '/home/junha/transferability/Music/data/maestro-v1.0.0/composer2id_map.pkl'  # Replace with your actual file path
# file_path = '/home/junha/transferability/Music/shift_table/bert-base-uncased_bert_token_mapping.pkl'
# try:
with open(file_path, 'rb') as file:
    data = torch.load(file)
print(f"Type of loaded data: {type(data)}")
print("Contents of the PKL file:")
print(data)
# except FileNotFoundError:
#     print("File not found. Check the file path.")
# except pickle.UnpicklingError:
#     print("The file is not a valid pickle file.")
# except EOFError:
#     print("The file is empty or corrupted.")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
# Out:
# Type of loaded data: <class 'dict'>
# Contents of the PKL file:
# {'Alban Berg': 0, 'Alexander Scriabin': 1, 'Antonio Soler': 2, 'Carl Maria von Weber': 3, 'Charles Gounod / Franz Liszt': 4, 'Claude Debussy': 5, 'César Franck': 6, 'Domenico Scarlatti': 7, 'Edvard Grieg': 8, 'Felix Mendelssohn': 9, 'Felix Mendelssohn / Sergei Rachmaninoff': 10, 'Franz Liszt': 11, 'Franz Liszt / Camille Saint-Saëns': 12, 'Franz Liszt / Vladimir Horowitz': 13, 'Franz Schubert': 14, 'Franz Schubert / Franz Liszt': 15, 'Franz Schubert / Leopold Godowsky': 16, 'Fritz Kreisler / Sergei Rachmaninoff': 17, 'Frédéric Chopin': 18, 'George Enescu': 19, 'George Frideric Handel': 20, 'Georges Bizet / Ferruccio Busoni': 21, 'Georges Bizet / Moritz Moszkowski': 22, 'Georges Bizet / Vladimir Horowitz': 23, 'Giuseppe Verdi / Franz Liszt': 24, 'Henry Purcell': 25, 'Isaac Albéniz': 26, 'Isaac Albéniz / Leopold Godowsky': 27, 'Jean-Philippe Rameau': 28, 'Johann Christian Fischer / Wolfgang Amadeus Mozart': 29, 'Johann Pachelbel': 30, 'Johann Sebastian Bach': 31, 'Johann Sebastian Bach / Egon Petri': 32, 'Johann Sebastian Bach / Ferruccio Busoni': 33, 'Johann Sebastian Bach / Franz Liszt': 34, 'Johann Sebastian Bach / Myra Hess': 35, 'Johann Strauss / Alfred Grünfeld': 36, 'Johannes Brahms': 37, 'Joseph Haydn': 38, 'Leoš Janáček': 39, 'Ludwig van Beethoven': 40, 'Mikhail Glinka / Mily Balakirev': 41, 'Mily Balakirev': 42, 'Modest Mussorgsky': 43, 'Muzio Clementi': 44, 'Niccolò Paganini / Franz Liszt': 45, 'Nikolai Medtner': 46, 'Nikolai Rimsky-Korsakov / Sergei Rachmaninoff': 47, 'Pyotr Ilyich Tchaikovsky': 48, 'Pyotr Ilyich Tchaikovsky / Mikhail Pletnev': 49, 'Pyotr Ilyich Tchaikovsky / Sergei Rachmaninoff': 50, 'Richard Wagner / Franz Liszt': 51, 'Robert Schumann': 52, 'Robert Schumann / Franz Liszt': 53, 'Sergei Rachmaninoff': 54, 'Sergei Rachmaninoff / György Cziffra': 55, 'Sergei Rachmaninoff / Vyacheslav Gryaznov': 56, 'Wolfgang Amadeus Mozart': 57}

# %%
# Print the shape of the embedding weight
print(f"Embedding weight shape: {data.weight.shape}")

# Print the number of embeddings and embedding dimension
print(f"Number of embeddings: {data.num_embeddings}")
print(f"Embedding dimension: {data.embedding_dim}")

# Print the actual embedding weights
print("Embedding weights:")
print(data.weight)

# If you want to see a specific embedding vector
print("First embedding vector:")
print(data.weight[0])

# Check if padding_idx is set
print(f"Padding index: {data.padding_idx}")

# Check if the embeddings are frozen
print(f"Embeddings frozen: {data.weight.requires_grad == False}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Print the shape of the embedding weight
# ----> 2 print(f"Embedding weight shape: {data.weight.shape}")
#       4 # Print the number of embeddings and embedding dimension
#       5 print(f"Number of embeddings: {data.num_embeddings}")
#
# AttributeError: 'Tensor' object has no attribute 'weight'

# %%
print(f"Min weight value: {torch.min(data.weight)}")
print(f"Max weight value: {torch.max(data.weight)}")
print(f"Mean weight value: {torch.mean(data.weight)}")
print(f"Standard deviation of weights: {torch.std(data.weight)}")
# Out:
# Min weight value: 2475.0
# Max weight value: 29537.0
# Mean weight value: 16094.0859375
# Standard deviation of weights: 8093.49462890625
