# %%
import pickle
import torch

file_path = '/home/junha/transferability/Music/data/pkl/256_train_data_filtered.pkl'  # Replace with your actual file path

# try:
with open(file_path, 'rb') as file:
    data = torch.load(file)
print(f"Type of loaded data: {type(data)}")
print("Contents of the PKL file:")
print(data)
# except FileNotFoundError:
#     print("File not found. Check the file path.")
# except pickle.UnpicklingError:
#     print("The file is not a valid pickle file.")
# except EOFError:
#     print("The file is empty or corrupted.")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
# Out:
# Type of loaded data: <class 'torch.Tensor'>
# Contents of the PKL file:
# tensor([[195, 200, 199,  ..., 197, 197, 189],
#         [203, 197, 193,  ..., 190, 199, 189],
#         [189, 194, 194,  ..., 188, 189, 186],
#         ...,
#         [200, 195, 188,  ..., 190, 187, 202],
#         [188, 202, 200,  ..., 193, 195, 188],
#         [192, 188, 195,  ..., 193, 195, 188]])

# %%
# Print the shape of the embedding weight
print(f"Embedding weight shape: {data.weight.shape}")

# Print the number of embeddings and embedding dimension
print(f"Number of embeddings: {data.num_embeddings}")
print(f"Embedding dimension: {data.embedding_dim}")

# Print the actual embedding weights
print("Embedding weights:")
print(data.weight)

# If you want to see a specific embedding vector
print("First embedding vector:")
print(data.weight[0])

# Check if padding_idx is set
print(f"Padding index: {data.padding_idx}")

# Check if the embeddings are frozen
print(f"Embeddings frozen: {data.weight.requires_grad == False}")
# Out:
# Embedding weight shape: torch.Size([256, 1])
# Number of embeddings: 256
# Embedding dimension: 1
# Embedding weights:
# Parameter containing:
# tensor([[7.3000e+01],
#         [1.2000e+01],
#         [3.3000e+02],
#         [1.7415e+04],
#         [2.6700e+02],
#         [2.9770e+03],
#         [2.8045e+04],
#         [1.1900e+02],
#         [2.9000e+01],
#         [6.4200e+02],
#         [4.6200e+02],
#         [4.2800e+02],
#         [2.8043e+04],
#         [5.7100e+02],
#         [4.3800e+02],
#         [4.1700e+02],
#         [4.3830e+04],
#         [5.0600e+02],
#         [9.0000e+01],
#         [1.7600e+02],
#         [7.2930e+03],
#         [2.9800e+02],
#         [2.1900e+02],
#         [1.1780e+03],
#         [1.0200e+03],
#         [1.7163e+04],
#         [1.2592e+04],
#         [7.0500e+02],
#         [3.9367e+04],
#         [1.3900e+02],
#         [2.5530e+03],
#         [6.0500e+02],
#         [2.9300e+02],
#         [4.8019e+04],
#         [1.0200e+02],
#         [3.3800e+02],
#         [4.1350e+03],
#         [4.9119e+04],
#         [2.4070e+03],
#         [2.8200e+02],
#         [3.5400e+02],
#         [3.2900e+02],
#         [7.4880e+03],
#         [1.2150e+03],
#         [4.0000e+00],
#         [3.6161e+04],
#         [3.8557e+04],
#         [2.8100e+02],
#         [3.0600e+02],
#         [3.0602e+04],
#         [2.5400e+02],
#         [1.1150e+03],
#         [2.4200e+02],
#         [5.2300e+02],
#         [4.2535e+04],
#         [2.1978e+04],
#         [3.4748e+04],
#         [1.7968e+04],
#         [1.1800e+02],
#         [1.7900e+02],
#         [2.4600e+02],
#         [3.6600e+02],
#         [4.0500e+02],
#         [3.3700e+02],
#         [1.3430e+03],
#         [3.4700e+02],
#         [3.9670e+03],
#         [2.7100e+02],
#         [3.8700e+02],
#         [5.1000e+02],
#         [3.7920e+03],
#         [2.6601e+04],
#         [2.2408e+04],
#         [6.1100e+02],
#         [2.5266e+04],
#         [5.9400e+02],
#         [2.4100e+02],
#         [1.5880e+03],
#         [1.0534e+04],
#         [2.5700e+02],
#         [6.3600e+02],
#         [3.6800e+02],
#         [1.2220e+03],
#         [5.5360e+03],
#         [3.3845e+04],
#         [6.2000e+02],
#         [1.5170e+03],
#         [1.7420e+03],
#         [1.0400e+02],
#         [7.6300e+02],
#         [4.4800e+02],
#         [1.0430e+03],
#         [3.8107e+04],
#         [3.9176e+04],
#         [8.7900e+02],
#         [4.1500e+02],
#         [2.6000e+02],
#         [1.0010e+03],
#         [4.1590e+04],
#         [2.6100e+02],
#         [1.9900e+03],
#         [1.2379e+04],
#         [8.7300e+02],
#         [4.1820e+03],
#         [8.6300e+02],
#         [2.6300e+03],
#         [8.5700e+02],
#         [2.5165e+04],
#         [1.1680e+03],
#         [9.9100e+02],
#         [2.3790e+03],
#         [5.7400e+02],
#         [1.4520e+03],
#         [1.6300e+03],
#         [2.8258e+04],
#         [2.9110e+03],
#         [6.4870e+03],
#         [1.4590e+03],
#         [7.1800e+02],
#         [1.0750e+03],
#         [5.3000e+02],
#         [4.6300e+02],
#         [6.7700e+02],
#         [5.8410e+03],
#         [2.5200e+03],
#         [1.1070e+04],
#         [2.6029e+04],
#         [7.8300e+02],
#         [9.4330e+03],
#         [8.0800e+02],
#         [1.8990e+03],
#         [6.2500e+02],
#         [4.2400e+02],
#         [7.5610e+03],
#         [4.1320e+03],
#         [2.2500e+02],
#         [1.0970e+03],
#         [3.8660e+03],
#         [6.8700e+02],
#         [4.8530e+04],
#         [4.5900e+02],
#         [1.0155e+04],
#         [1.7500e+02],
#         [1.7920e+03],
#         [1.4690e+03],
#         [1.9675e+04],
#         [8.5800e+02],
#         [2.0010e+03],
#         [8.3040e+03],
#         [3.4630e+03],
#         [3.1810e+03],
#         [3.9980e+03],
#         [3.3806e+04],
#         [5.0000e+02],
#         [2.5354e+04],
#         [2.1200e+02],
#         [2.0500e+03],
#         [9.7070e+03],
#         [4.7947e+04],
#         [1.5060e+03],
#         [1.9750e+03],
#         [4.3390e+03],
#         [4.0706e+04],
#         [2.3687e+04],
#         [2.4500e+02],
#         [2.8690e+04],
#         [4.8250e+03],
#         [1.7486e+04],
#         [1.4087e+04],
#         [2.3199e+04],
#         [3.9760e+03],
#         [1.0782e+04],
#         [6.5040e+03],
#         [2.5903e+04],
#         [4.8920e+03],
#         [1.9570e+03],
#         [1.2420e+03],
#         [9.9960e+03],
#         [1.9160e+03],
#         [2.7643e+04],
#         [4.6840e+04],
#         [4.6200e+04],
#         [7.5700e+02],
#         [2.4130e+03],
#         [5.6500e+02],
#         [4.2734e+04],
#         [6.2700e+02],
#         [3.9700e+02],
#         [5.3400e+02],
#         [2.0414e+04],
#         [1.4390e+03],
#         [1.3340e+03],
#         [9.6700e+02],
#         [1.6940e+03],
#         [1.0730e+03],
#         [1.6100e+03],
#         [2.0068e+04],
#         [7.1700e+02],
#         [4.9500e+02],
#         [1.2376e+04],
#         [3.6310e+03],
#         [8.9500e+02],
#         [4.1840e+03],
#         [4.0310e+03],
#         [3.0360e+03],
#         [3.8090e+03],
#         [8.6930e+03],
#         [2.4030e+03],
#         [3.8650e+03],
#         [4.3250e+03],
#         [5.4800e+02],
#         [4.6910e+03],
#         [3.8940e+03],
#         [1.1160e+03],
#         [1.4170e+03],
#         [8.4600e+02],
#         [3.6146e+04],
#         [1.6435e+04],
#         [1.0859e+04],
#         [1.9600e+02],
#         [4.1380e+03],
#         [1.0710e+03],
#         [2.1860e+03],
#         [8.5900e+02],
#         [1.7137e+04],
#         [8.7600e+02],
#         [1.7900e+03],
#         [1.9880e+03],
#         [1.0900e+03],
#         [3.1818e+04],
#         [1.7940e+03],
#         [7.1000e+02],
#         [3.3610e+03],
#         [6.1190e+03],
#         [1.3637e+04],
#         [4.0630e+03],
#         [2.4810e+04],
#         [7.1100e+03],
#         [1.3400e+02],
#         [2.9870e+03],
#         [4.8556e+04],
#         [3.3400e+03],
#         [4.9300e+02],
#         [7.2100e+03],
#         [4.5266e+04],
#         [3.5800e+04],
#         [1.9322e+04],
#         [1.0690e+03],
#         [2.6800e+02],
#         [1.0800e+04],
#         [1.7550e+03],
#         [1.7410e+03],
#         [2.2530e+03],
#         [3.6620e+03],
#         [3.2557e+04],
#         [4.2910e+03]], requires_grad=True)
# First embedding vector:
# tensor([73.], grad_fn=<SelectBackward0>)
# Padding index: None
# Embeddings frozen: False

# %%
print(f"Min weight value: {torch.min(data.weight)}")
print(f"Max weight value: {torch.max(data.weight)}")
print(f"Mean weight value: {torch.mean(data.weight)}")
print(f"Standard deviation of weights: {torch.std(data.weight)}")
# Out:
# Min weight value: 2475.0
# Max weight value: 29537.0
# Mean weight value: 16094.0859375
# Standard deviation of weights: 8093.49462890625
