# %%
import pickle
import torch

file_path = '/home/junha/transferability/Protein/preprocess_input/localization/cached_dev_input_ids_localization_FacebookAI_roberta-base_64.pkl'
# try:
with open(file_path, 'rb') as file:
    data = torch.load(file)
print(f"Type of loaded data: {type(data)}")
print("Contents of the PKL file:")
print(data)
# except FileNotFoundError:
#     print("File not found. Check the file path.")
# except pickle.UnpicklingError:
#     print("The file is not a valid pickle file.")
# except EOFError:
#     print("The file is empty or corrupted.")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
# Out:
# Type of loaded data: <class 'torch.Tensor'>
# Contents of the PKL file:
# tensor([[ 0, 13,  1,  ...,  8,  4,  2],
#         [ 0, 13,  1,  ..., 20, 20,  2],
#         [ 0, 13, 16,  ...,  7, 20,  2],
#         ...,
#         [ 0, 13,  7,  ..., 10,  5,  2],
#         [ 0, 13, 12,  ..., 11, 12,  2],
#         [ 0, 13, 16,  ...,  6, 16,  2]])

# %%
# Print the shape of the embedding weight
print(f"Embedding weight shape: {data.weight.shape}")

# Print the number of embeddings and embedding dimension
print(f"Number of embeddings: {data.num_embeddings}")
print(f"Embedding dimension: {data.embedding_dim}")

# Print the actual embedding weights
print("Embedding weights:")
print(data.weight)

# If you want to see a specific embedding vector
print("First embedding vector:")
print(data.weight[0])

# Check if padding_idx is set
print(f"Padding index: {data.padding_idx}")

# Check if the embeddings are frozen
print(f"Embeddings frozen: {data.weight.requires_grad == False}")
# Out:
# Embedding weight shape: torch.Size([256, 1])
# Number of embeddings: 256
# Embedding dimension: 1
# Embedding weights:
# Parameter containing:
# tensor([[5442.],
#         [ 702.],
#         [7442.],
#         [2209.],
#         [1921.],
#         [2861.],
#         [4689.],
#         [ 123.],
#         [1240.],
#         [5023.],
#         [ 753.],
#         [ 738.],
#         [1346.],
#         [1728.],
#         [ 943.],
#         [3360.],
#         [7481.],
#         [2339.],
#         [3309.],
#         [ 114.],
#         [1066.],
#         [1394.],
#         [1400.],
#         [ 113.],
#         [2428.],
#         [6206.],
#         [4028.],
#         [1282.],
#         [3634.],
#         [3198.],
#         [1057.],
#         [4634.],
#         [5543.],
#         [1059.],
#         [1957.],
#         [6858.],
#         [ 124.],
#         [2137.],
#         [3780.],
#         [1265.],
#         [2595.],
#         [7368.],
#         [ 886.],
#         [1447.],
#         [2128.],
#         [2512.],
#         [3613.],
#         [6722.],
#         [1366.],
#         [3949.],
#         [1894.],
#         [1092.],
#         [1825.],
#         [1154.],
#         [1333.],
#         [2466.],
#         [3209.],
#         [4374.],
#         [ 852.],
#         [1347.],
#         [7270.],
#         [ 889.],
#         [ 125.],
#         [4685.],
#         [7269.],
#         [1814.],
#         [4680.],
#         [6725.],
#         [7032.],
#         [1385.],
#         [6963.],
#         [7028.],
#         [3346.],
#         [3683.],
#         [5739.],
#         [1213.],
#         [1220.],
#         [2970.],
#         [2357.],
#         [4273.],
#         [3419.],
#         [1999.],
#         [ 131.],
#         [ 699.],
#         [ 126.],
#         [8039.],
#         [6555.],
#         [7274.],
#         [2424.],
#         [5143.],
#         [3633.],
#         [ 680.],
#         [3413.],
#         [7509.],
#         [2205.],
#         [1169.],
#         [2225.],
#         [7350.],
#         [3717.],
#         [2349.],
#         [1355.],
#         [7676.],
#         [7279.],
#         [5101.],
#         [1380.],
#         [ 765.],
#         [1724.],
#         [5221.],
#         [8108.],
#         [6629.],
#         [2772.],
#         [ 128.],
#         [3160.],
#         [3289.],
#         [ 691.],
#         [2552.],
#         [4958.],
#         [3121.],
#         [4412.],
#         [ 769.],
#         [2382.],
#         [1305.],
#         [2797.],
#         [ 127.],
#         [7768.],
#         [1922.],
#         [7674.],
#         [5195.],
#         [8024.],
#         [ 100.],
#         [4638.],
#         [ 511.],
#         [2399.],
#         [ 170.],
#         [ 510.],
#         [8020.],
#         [8021.],
#         [ 704.],
#         [1762.],
#         [ 671.],
#         [ 782.],
#         [1920.],
#         [3299.],
#         [3189.],
#         [3221.],
#         [ 118.],
#         [3300.],
#         [1469.],
#         [4158.],
#         [6121.],
#         [1744.],
#         [8038.],
#         [1751.],
#         [ 809.],
#         [1765.],
#         [ 119.],
#         [6956.],
#         [2768.],
#         [ 711.],
#         [ 749.],
#         [3176.],
#         [ 677.],
#         [3172.],
#         [ 517.],
#         [ 518.],
#         [ 712.],
#         [1139.],
#         [1062.],
#         [ 868.],
#         [5018.],
#         [2207.],
#         [4495.],
#         [ 679.],
#         [2356.],
#         [3152.],
#         [1399.],
#         [ 722.],
#         [ 800.],
#         [6205.],
#         [ 185.],
#         [2157.],
#         [3124.],
#         [3298.],
#         [1146.],
#         [3315.],
#         [1071.],
#         [4500.],
#         [2094.],
#         [4294.],
#         [2110.],
#         [3696.],
#         [ 117.],
#         [ 520.],
#         [ 519.],
#         [3229.],
#         [3175.],
#         [ 678.],
#         [1298.],
#         [3791.],
#         [2527.],
#         [1350.],
#         [ 754.],
#         [2119.],
#         [ 855.],
#         [5401.],
#         [1046.],
#         [4507.],
#         [1168.],
#         [1266.],
#         [5445.],
#         [4289.],
#         [6158.],
#         [3173.],
#         [3215.],
#         [1912.],
#         [1398.],
#         [ 122.],
#         [6887.],
#         [ 818.],
#         [5632.],
#         [2548.],
#         [1377.],
#         [7770.],
#         [1914.],
#         [2255.],
#         [3862.],
#         [1164.],
#         [5645.],
#         [4991.],
#         [ 676.],
#         [ 807.],
#         [1217.],
#         [2456.],
#         [5440.],
#         [4413.],
#         [3297.],
#         [ 752.],
#         [6662.],
#         [1184.],
#         [1277.],
#         [4906.],
#         [6134.],
#         [2792.],
#         [2533.],
#         [1281.],
#         [4989.],
#         [7027.],
#         [2398.],
#         [ 833.],
#         [1378.],
#         [ 686.],
#         [5635.],
#         [4415.],
#         [1519.],
#         [2336.],
#         [3136.]], requires_grad=True)
# First embedding vector:
# tensor([5442.], grad_fn=<SelectBackward0>)
# Padding index: None
# Embeddings frozen: False

# %%
print(f"Min weight value: {torch.min(data.weight)}")
print(f"Max weight value: {torch.max(data.weight)}")
print(f"Mean weight value: {torch.mean(data.weight)}")
print(f"Standard deviation of weights: {torch.std(data.weight)}")
# Out:
# Min weight value: 2475.0
# Max weight value: 29537.0
# Mean weight value: 16094.0859375
# Standard deviation of weights: 8093.49462890625
